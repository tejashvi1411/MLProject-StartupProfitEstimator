# %%
import pandas as pd
import numpy as np 
import seaborn as sns

# %%
df = pd.DataFrame(columns =['Age', 'Gender','Stream', 'Internships', 'CGPA', 'Hostel','HistoryOfBacklogs','PlacedOrNot'])

# %%
df
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Stream, Internships, CGPA, Hostel, HistoryOfBacklogs, PlacedOrNot]
# Index: []

# %%
df['Age']= np.random.randint(21, 24, 2966)

# %%
df.reset_index(inplace=True)

# %%
df['index']= np.random.randint(1, 2966, 2966)

# %%
df['Age'][0:1500]=np.random.randint(21, 23, 1500)
# Out:
# <ipython-input-7-c7dae011f369>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'][0:1500]=np.random.randint(21, 23, 1500)
# C:\Users\2192a\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df['Age'][1500:1900]=np.random.randint(20, 25, 400)
# Out:
# <ipython-input-8-3e25b8ffbcde>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'][1500:1900]=np.random.randint(20, 25, 400)

# %%
df['Age'][1900:2500]=np.random.randint(19, 23, 600)
# Out:
# <ipython-input-9-fd8aea94ea27>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'][1900:2500]=np.random.randint(19, 23, 600)

# %%
df['Age'][2500:2800]=np.random.randint(20, 22, 300)
# Out:
# <ipython-input-10-83a774da022e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'][2500:2800]=np.random.randint(20, 22, 300)

# %%
df['Age'][1300:1360]=np.random.randint(24, 27, 60)
df['Age'][700:760]=np.random.randint(23, 27, 60)
df['Age'][100:160]=np.random.randint(23, 25, 60)
df["Age"].iloc[2333]=29
df["Age"].iloc[1444]=28
df["Age"].iloc[2446]=28
df["Age"].iloc[448]=28
df["Age"].iloc[550]=30
# Out:
# <ipython-input-11-ec26eb5f7e4a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'][1300:1360]=np.random.randint(24, 27, 60)
# <ipython-input-11-ec26eb5f7e4a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'][700:760]=np.random.randint(23, 27, 60)
# <ipython-input-11-ec26eb5f7e4a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'][100:160]=np.random.randint(23, 25, 60)

# %%
df
# Out:
#       index  Age Gender Stream Internships CGPA Hostel HistoryOfBacklogs  \
# 0      1296   22    NaN    NaN         NaN  NaN    NaN               NaN
# 1      2635   21    NaN    NaN         NaN  NaN    NaN               NaN
# 2      1740   22    NaN    NaN         NaN  NaN    NaN               NaN
# 3      2019   21    NaN    NaN         NaN  NaN    NaN               NaN
# 4       263   22    NaN    NaN         NaN  NaN    NaN               NaN
# ...     ...  ...    ...    ...         ...  ...    ...               ...
# 2961   1807   23    NaN    NaN         NaN  NaN    NaN               NaN
# 2962      9   23    NaN    NaN         NaN  NaN    NaN               NaN
# 2963   1902   22    NaN    NaN         NaN  NaN    NaN               NaN
# 2964   2642   22    NaN    NaN         NaN  NaN    NaN               NaN
# 2965    455   23    NaN    NaN         NaN  NaN    NaN               NaN
#
#      PlacedOrNot
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# ...

# %%
for i in range(2966):
    if df['index'].iloc[i]>= 912 and  df['index'].iloc[i]%5==0:
        df['Gender'].iloc[i]="Female"
    elif df['index'].iloc[i]< 912 and df['index'].iloc[i]%12==0:
        df['Gender'].iloc[i]="Female"
    else:
        df['Gender'].iloc[i]="Male"
# Out:
# C:\Users\2192a\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df
# Out:
#       index  Age  Gender Stream Internships CGPA Hostel HistoryOfBacklogs  \
# 0      1296   22    Male    NaN         NaN  NaN    NaN               NaN
# 1      2635   21  Female    NaN         NaN  NaN    NaN               NaN
# 2      1740   22  Female    NaN         NaN  NaN    NaN               NaN
# 3      2019   21    Male    NaN         NaN  NaN    NaN               NaN
# 4       263   22    Male    NaN         NaN  NaN    NaN               NaN
# ...     ...  ...     ...    ...         ...  ...    ...               ...
# 2961   1807   23    Male    NaN         NaN  NaN    NaN               NaN
# 2962      9   23    Male    NaN         NaN  NaN    NaN               NaN
# 2963   1902   22    Male    NaN         NaN  NaN    NaN               NaN
# 2964   2642   22    Male    NaN         NaN  NaN    NaN               NaN
# 2965    455   23    Male    NaN         NaN  NaN    NaN               NaN
#
#      PlacedOrNot
# 0            NaN
# 1            NaN
# 2            NaN
# ...

# %%
for i in range(2966):
    if df['index'].iloc[i]<= 399:
        df['Stream'].iloc[i]="Mechanical"
    if df['index'].iloc[i]>= 399 and df['index'].iloc[i]<750:
        df['Stream'].iloc[i]="Civil"
    if df['index'].iloc[i]>= 750 and df['index'].iloc[i]<1111:
        df['Stream'].iloc[i]="Electrical"
    if df['index'].iloc[i]>=1111 and df['index'].iloc[i]<1544:
        df['Stream'].iloc[i]="Electronics And Communication"
    if df['index'].iloc[i]>= 1544 and df['index'].iloc[i]<2226:
        df['Stream'].iloc[i]="Information Technology"
    if df['index'].iloc[i]>= 2226:
        df['Stream'].iloc[i]="Computer Science"
# Out:
# C:\Users\2192a\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df[2900:2950]
# Out:
#       index  Age  Gender                         Stream Internships CGPA  \
# 2900   2749   22    Male               Computer Science         NaN  NaN
# 2901   1301   21    Male  Electronics And Communication         NaN  NaN
# 2902   2395   23  Female               Computer Science         NaN  NaN
# 2903   1147   23    Male  Electronics And Communication         NaN  NaN
# 2904    944   22    Male                     Electrical         NaN  NaN
# 2905   2144   23    Male         Information Technology         NaN  NaN
# 2906   1391   21    Male  Electronics And Communication         NaN  NaN
# 2907   1199   22    Male  Electronics And Communication         NaN  NaN
# 2908   1301   21    Male  Electronics And Communication         NaN  NaN
# 2909   2118   23    Male         Information Technology         NaN  NaN
# 2910   2056   21    Male         Information Technology         NaN  NaN
# 2911   2008   23    Male         Information Technology         NaN  NaN
# ...

# %%
for i in range(2966):
    if df['index'].iloc[i]<1002 and df['index'].iloc[i]%3==0:
        df['Internships'].iloc[i]=1
    elif df['index'].iloc[i]<1002 and df['index'].iloc[i]%16==0:
        df['Internships'].iloc[i]=2
    elif df['index'].iloc[i]<1002 and df['index'].iloc[i]%58==0:
        df['Internships'].iloc[i]=3
    elif df['index'].iloc[i]>=1002 and df['index'].iloc[i]%11==0:
        df['Internships'].iloc[i]=2
    elif df['index'].iloc[i]>=1002 and df['index'].iloc[i]%34==0:
        df['Internships'].iloc[i]=3
    elif df['index'].iloc[i]>=1002 and df['index'].iloc[i]%2==0:
        df['Internships'].iloc[i]=1
    elif df['index'].iloc[i]>=1800 and df['index'].iloc[i]%7==0:
        df['Internships'].iloc[i]=2
        
    else:
        df['Internships'].iloc[i]=0
        
df['Internships'][1000:1150]= np.random.randint(1, 3, 150)
df['Internships'][600:650]= np.random.randint(1, 3, 50)
# Out:
# C:\Users\2192a\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# <ipython-input-17-bc205c29d996>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Internships'][1000:1150]= np.random.randint(1, 3, 150)
# <ipython-input-17-bc205c29d996>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df
# Out:
#       index  Age  Gender                         Stream Internships CGPA  \
# 0      1296   22    Male  Electronics And Communication           1  NaN
# 1      2635   21  Female               Computer Science           0  NaN
# 2      1740   22  Female         Information Technology           1  NaN
# 3      2019   21    Male         Information Technology           0  NaN
# 4       263   22    Male                     Mechanical           0  NaN
# ...     ...  ...     ...                            ...         ...  ...
# 2961   1807   23    Male         Information Technology           0  NaN
# 2962      9   23    Male                     Mechanical           1  NaN
# 2963   1902   22    Male         Information Technology           1  NaN
# 2964   2642   22    Male               Computer Science           1  NaN
# 2965    455   23    Male                          Civil           0  NaN
#
#      Hostel HistoryOfBacklogs PlacedOrNot
# 0       NaN               NaN         NaN
# ...

# %%
sns.displot(df, x="Internships")

# %%
df['CGPA']= np.random.randint(6, 9.1, 2966)
df['CGPA'][100:199]= np.random.randint(5, 8, 99)
df['CGPA'][1100:1350]= np.random.randint(7, 10, 250)
df['CGPA'][2100:2190]= np.random.randint(5, 10, 90)
df['CGPA'][1578:1600]= np.random.randint(5, 7, 22)
df['CGPA'][56:82]= np.random.randint(8, 10, 26)
df['CGPA'][700:740]= np.random.randint(6, 10, 40)
df['CGPA'][400:411]= np.random.randint(5, 7, 11)
df['CGPA'][2600:2740]= np.random.randint(7, 10, 140)
df['CGPA'][1700:1767]= np.random.randint(5, 7, 67)
df['CGPA'][1300:1387]= np.random.randint(6, 8, 87)
df['CGPA'][1900:2007]= np.random.randint(7, 9, 107)
# Out:
# <ipython-input-20-30147272d9bc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CGPA'][100:199]= np.random.randint(5, 8, 99)
# C:\Users\2192a\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# <ipython-input-20-30147272d9bc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df
# Out:
#       index  Age  Gender                         Stream Internships  CGPA  \
# 0      1296   22    Male  Electronics And Communication           1     8
# 1      2635   21  Female               Computer Science           0     7
# 2      1740   22  Female         Information Technology           1     6
# 3      2019   21    Male         Information Technology           0     8
# 4       263   22    Male                     Mechanical           0     8
# ...     ...  ...     ...                            ...         ...   ...
# 2961   1807   23    Male         Information Technology           0     7
# 2962      9   23    Male                     Mechanical           1     7
# 2963   1902   22    Male         Information Technology           1     7
# 2964   2642   22    Male               Computer Science           1     7
# 2965    455   23    Male                          Civil           0     8
#
#      Hostel HistoryOfBacklogs PlacedOrNot
# ...

# %%
sns.displot(df, x="CGPA")

# %%
sns.displot(df, x="Internships")

# %%
for i in range(2966):
    if df['index'].iloc[i] >= 2279 and df['index'].iloc[i]%5==0:
        df['Hostel'].iloc[i]=1
    elif df['index'].iloc[i]< 2279 and df['index'].iloc[i]>=1000 and df['index'].iloc[i]%8==0:
        df['Hostel'].iloc[i]=1
    elif df['index'].iloc[i]< 1000 and df['index'].iloc[i]>=450 and df['index'].iloc[i]%9==1:
        df['Hostel'].iloc[i]=1
    elif df['index'].iloc[i]< 450 and df["index"].iloc[i]%11:
        df['Hostel'].iloc[i]=1
    else:
        df['Hostel'].iloc[i]=0
# Out:
# C:\Users\2192a\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
sns.displot(df, x="Hostel")

# %%
df[70:120]
# Out:
#      index  Age  Gender                         Stream Internships  CGPA  \
# 70    1046   22    Male                     Electrical           1     8
# 71    1643   22    Male         Information Technology           0     9
# 72    2754   22    Male               Computer Science           3     9
# 73    2193   21    Male         Information Technology           0     8
# 74    2214   22    Male         Information Technology           1     9
# 75     475   21    Male                          Civil           0     8
# 76      61   21    Male                     Mechanical           0     9
# 77     260   22    Male                     Mechanical           0     8
# 78    1663   22    Male         Information Technology           0     8
# 79    2786   21    Male               Computer Science           1     8
# 80     689   21    Male                          Civil           0     9
# 81    2592   21    Male               Computer Science           1     9
# ...

# %%
df
# Out:
#       index  Age  Gender                         Stream Internships  CGPA  \
# 0      1296   22    Male  Electronics And Communication           1     8
# 1      2635   21  Female               Computer Science           0     7
# 2      1740   22  Female         Information Technology           1     6
# 3      2019   21    Male         Information Technology           0     8
# 4       263   22    Male                     Mechanical           0     8
# ...     ...  ...     ...                            ...         ...   ...
# 2961   1807   23    Male         Information Technology           0     7
# 2962      9   23    Male                     Mechanical           1     7
# 2963   1902   22    Male         Information Technology           1     7
# 2964   2642   22    Male               Computer Science           1     7
# 2965    455   23    Male                          Civil           0     8
#
#      Hostel HistoryOfBacklogs PlacedOrNot
# ...

# %%
df.describe()
# Out:
#              index          Age         CGPA
# count  2966.000000  2966.000000  2966.000000
# mean   1502.282873    21.485840     7.073837
# std     865.690877     1.324933     0.967748
# min       1.000000    19.000000     5.000000
# 25%     753.250000    21.000000     6.000000
# 50%    1520.500000    21.000000     7.000000
# 75%    2259.000000    22.000000     8.000000
# max    2965.000000    30.000000     9.000000

# %%
for i in range(2966):
    if df['index'].iloc[i] >= 2379 and df['index'].iloc[i]%6==1:
        df['HistoryOfBacklogs'].iloc[i]=1
    elif df['index'].iloc[i]< 2379 and df['index'].iloc[i]>=1800 and df['index'].iloc[i]%7==3:
        df['HistoryOfBacklogs'].iloc[i]=1
    elif df['index'].iloc[i]< 1800 and df['index'].iloc[i]>=1450 and df['index'].iloc[i]%5==1:
        df['HistoryOfBacklogs'].iloc[i]=1
    elif df['index'].iloc[i]< 1450 and df['index'].iloc[i]>=790 and df["index"].iloc[i]%4==0:
        df['HistoryOfBacklogs'].iloc[i]=1
    elif df['index'].iloc[i]< 790 and df['index'].iloc[i]>=223 and df['index'].iloc[i]%7==1:
        df['HistoryOfBacklogs'].iloc[i]=1
    elif df['index'].iloc[i]< 223 and df["index"].iloc[i]%4==3:
        df['HistoryOfBacklogs'].iloc[i]=1
    else:
        df['HistoryOfBacklogs'].iloc[i]=0
# Out:
# C:\Users\2192a\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
sns.displot(df, x="HistoryOfBacklogs")

# %%
df
# Out:
#       index  Age  Gender                         Stream Internships  CGPA  \
# 0      1296   22    Male  Electronics And Communication           1     8
# 1      2635   21  Female               Computer Science           0     7
# 2      1740   22  Female         Information Technology           1     6
# 3      2019   21    Male         Information Technology           0     8
# 4       263   22    Male                     Mechanical           0     8
# ...     ...  ...     ...                            ...         ...   ...
# 2961   1807   23    Male         Information Technology           0     7
# 2962      9   23    Male                     Mechanical           1     7
# 2963   1902   22    Male         Information Technology           1     7
# 2964   2642   22    Male               Computer Science           1     7
# 2965    455   23    Male                          Civil           0     8
#
#      Hostel HistoryOfBacklogs PlacedOrNot
# ...

# %%
for i in range(2966):    
    if df['Age'].iloc[i]== 22 and df['CGPA'].iloc[i]==7:
        df['PlacedOrNot'].iloc[i]=0
    elif df['Stream'].iloc[i]=="Computer Science" and df['Stream'].iloc[i]=="Information Technology" and df['Internships'].iloc[i]>=1:
        df['PlacedOrNot'].iloc[i]=1
    elif df['Stream'].iloc[i]=="Mechanical" and df['Stream'].iloc[i]=="Civil" and df['Internships'].iloc[i]==0:
        df['PlacedOrNot'].iloc[i]=0
    elif df['Stream'].iloc[i]=="Electronics And Communication" and df['Stream'].iloc[i]=="Information Technology" and df['HistoryOfBacklogs'].iloc[i]==0:
        df['PlacedOrNot'].iloc[i]=1
    elif df['Stream'].iloc[i]=="Information Technology" and df['Stream'].iloc[i]=="Computer Science" and df['CGPA'].iloc[i]>=7:
        df['PlacedOrNot'].iloc[i]=1
    elif df['Stream'].iloc[i]=="Information Technology" and df['Stream'].iloc[i]=="Computer Science" and df['Age'].iloc[i]>=22:
        df['PlacedOrNot'].iloc[i]=1
    elif df['Stream'].iloc[i]=="Electronics And Communication" and df['Stream'].iloc[i]=="Civil" and df['CGPA'].iloc[i]<=6:
        df['PlacedOrNot'].iloc[i]=0
    elif df['Stream'].iloc[i]=="Civil" and df['Hostel'].iloc[i]==0 and df['CGPA'].iloc[i]<=7:
        df['PlacedOrNot'].iloc[i]=0
    elif df['Stream'].iloc[i]=="Electronics And Communication" and df['index'].iloc[i]==1 and df['CGPA'].iloc[i]>=6:
        df['PlacedOrNot'].iloc[i]=1
    elif df['Stream'].iloc[i]=="Electrical" and df['Internships'].iloc[i]>=1 and df['CGPA'].iloc[i]>=7:
        df['PlacedOrNot'].iloc[i]=1
    elif df['Stream'].iloc[i]=="Electrical" and df['Stream'].iloc[i]=="Mechanical" and df['CGPA'].iloc[i]>=8:
        df['PlacedOrNot'].iloc[i]=1
    elif df['Internships'].iloc[i]>=2 and df['HistoryOfBacklogs'].iloc[i]==0 and df["CGPA"].iloc[i]>=6:
        df['PlacedOrNot'].iloc[i]=1
    elif df['Age'].iloc[i]>=22 and df["index"].iloc[i]<=2675 and df["index"].iloc[i]>=2567:
        df['PlacedOrNot'].iloc[i]=1
    elif df['CGPA'].iloc[i]==8 and df["index"].iloc[i]<=343 and df["index"].iloc[i]>=465:
        df['PlacedOrNot'].iloc[i]=1
    elif df['CGPA'].iloc[i]==7 and df["index"].iloc[i]<=1345 and df["index"].iloc[i]>=1100:
        df['PlacedOrNot'].iloc[i]=1
    else:
        df['PlacedOrNot'].iloc[i]=0

df['PlacedOrNot'][1500:1650]= np.random.randint(0, 2, 150)
df['PlacedOrNot'][2100:2190]= np.random.randint(0, 2, 90)
df['PlacedOrNot'][90:180]= np.random.randint(0, 2, 90)
df['PlacedOrNot'][270:360]= np.random.randint(0, 2, 90)
df['PlacedOrNot'][450:510]= np.random.randint(0, 2, 60)

        
for i in range(2966):
    if df['CGPA'].iloc[i]>=8:
        df['PlacedOrNot'].iloc[i]=1
    elif df['CGPA'].iloc[i]<=5:
        df['PlacedOrNot'].iloc[i]=0
    elif df['CGPA'].iloc[i]<=6 and df['Age'].iloc[i]>23:
        df['PlacedOrNot'].iloc[i]=1
# Out:
# C:\Users\2192a\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# <ipython-input-116-81550d596367>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PlacedOrNot'][1500:1650]= np.random.randint(0, 2, 150)
# <ipython-input-116-81550d596367>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df["PlacedOrNot"].value_counts()
# Out:
# 1    1600
# 0    1366
# Name: PlacedOrNot, dtype: int64

# %%
df.corr()
# Out:
#                       index       Age  Internships      CGPA    Hostel  \
# index              1.000000  0.036240     0.174589 -0.018380 -0.355697
# Age                0.036240  1.000000     0.006552 -0.119787  0.003042
# Internships        0.174589  0.006552     1.000000  0.023496  0.004617
# CGPA              -0.018380 -0.119787     0.023496  1.000000  0.014991
# Hostel            -0.355697  0.003042     0.004617  0.014991  1.000000
# HistoryOfBacklogs -0.037292 -0.042586    -0.015118  0.002576  0.103506
# PlacedOrNot        0.012730  0.034036     0.161021  0.589226  0.002320
#
#                    HistoryOfBacklogs  PlacedOrNot
# index                      -0.037292     0.012730
# Age                        -0.042586     0.034036
# Internships                -0.015118     0.161021
# CGPA                        0.002576     0.589226
# Hostel                      0.103506     0.002320
# HistoryOfBacklogs           1.000000     0.004318
# ...

# %%
df["PlacedOrNot"].iloc[1]=1
df["PlacedOrNot"].iloc[2]=1
df["PlacedOrNot"].iloc[29]=1
df["PlacedOrNot"].iloc[34]=1

df["PlacedOrNot"].iloc[55]=1
df["PlacedOrNot"].iloc[36]=1
df["PlacedOrNot"].iloc[109]=1
df["PlacedOrNot"].iloc[116]=1

df["PlacedOrNot"].iloc[117]=1
df["PlacedOrNot"].iloc[118]=1
df["PlacedOrNot"].iloc[120]=1
df["PlacedOrNot"].iloc[122]=1

df["PlacedOrNot"].iloc[123]=1
df["PlacedOrNot"].iloc[129]=1
df["PlacedOrNot"].iloc[142]=1
df["PlacedOrNot"].iloc[137]=1

df["PlacedOrNot"].iloc[140]=1
df["PlacedOrNot"].iloc[143]=1
df["PlacedOrNot"].iloc[144]=1
df["PlacedOrNot"].iloc[149]=1

df["PlacedOrNot"].iloc[152]=1
df["PlacedOrNot"].iloc[159]=1
df["PlacedOrNot"].iloc[154]=1
df["PlacedOrNot"].iloc[303]=1

df["PlacedOrNot"].iloc[307]=1
df["PlacedOrNot"].iloc[308]=1
df["PlacedOrNot"].iloc[338]=1
df["PlacedOrNot"].iloc[340]=1

df["PlacedOrNot"].iloc[1300]=1
df["PlacedOrNot"].iloc[1336]=1
df["PlacedOrNot"].iloc[1337]=1
df["PlacedOrNot"].iloc[1351]=1

df["PlacedOrNot"].iloc[1354]=1
df["PlacedOrNot"].iloc[1345]=1
df["PlacedOrNot"].iloc[1346]=1
df["PlacedOrNot"].iloc[1347]=1

df["PlacedOrNot"].iloc[1348]=1
df["PlacedOrNot"].iloc[1352]=1
df["PlacedOrNot"].iloc[1354]=1
df["PlacedOrNot"].iloc[1509]=1

df["PlacedOrNot"].iloc[1514]=1
df["PlacedOrNot"].iloc[1558]=1
df["PlacedOrNot"].iloc[1640]=1
df["PlacedOrNot"].iloc[1659]=1

df["PlacedOrNot"].iloc[1651]=1
df["PlacedOrNot"].iloc[1902]=1
df["PlacedOrNot"].iloc[1903]=1
df["PlacedOrNot"].iloc[1200]=1

df["PlacedOrNot"].iloc[1223]=1
df["PlacedOrNot"].iloc[1244]=1
df["PlacedOrNot"].iloc[1909]=1
df["PlacedOrNot"].iloc[1910]=1

df["PlacedOrNot"].iloc[1926]=1
df["PlacedOrNot"].iloc[1927]=1
df["PlacedOrNot"].iloc[1947]=1
df["PlacedOrNot"].iloc[1948]=1

df["PlacedOrNot"].iloc[2201]=1
df["PlacedOrNot"].iloc[2205]=1
df["PlacedOrNot"].iloc[2206]=1
df["PlacedOrNot"].iloc[2207]=1

df["PlacedOrNot"].iloc[2216]=1
df["PlacedOrNot"].iloc[2211]=1
df["PlacedOrNot"].iloc[2222]=1
df["PlacedOrNot"].iloc[2207]=1

df["PlacedOrNot"].iloc[2255]=1
df["PlacedOrNot"].iloc[2256]=1
df["PlacedOrNot"].iloc[2257]=1
df["PlacedOrNot"].iloc[2258]=1

df["PlacedOrNot"].iloc[601]=1
df["PlacedOrNot"].iloc[605]=1
df["PlacedOrNot"].iloc[606]=1
df["PlacedOrNot"].iloc[620]=1

df["PlacedOrNot"].iloc[638]=1
df["PlacedOrNot"].iloc[641]=1
df["PlacedOrNot"].iloc[647]=1
df["PlacedOrNot"].iloc[648]=1

df["PlacedOrNot"].iloc[652]=1
df["PlacedOrNot"].iloc[716]=1
df["PlacedOrNot"].iloc[720]=1
df["PlacedOrNot"].iloc[744]=1

df["PlacedOrNot"].iloc[730]=1
df["PlacedOrNot"].iloc[746]=1
df["PlacedOrNot"].iloc[748]=1
df["PlacedOrNot"].iloc[761]=1

df["PlacedOrNot"].iloc[763]=1
df["PlacedOrNot"].iloc[760]=1
df["PlacedOrNot"].iloc[764]=1
df["PlacedOrNot"].iloc[766]=1

df["PlacedOrNot"].iloc[768]=1
df["PlacedOrNot"].iloc[774]=1
df["PlacedOrNot"].iloc[777]=1
df["PlacedOrNot"].iloc[796]=1

df["PlacedOrNot"].iloc[800]=1
df["PlacedOrNot"].iloc[801]=1
df["PlacedOrNot"].iloc[803]=1
df["PlacedOrNot"].iloc[808]=1

df["PlacedOrNot"].iloc[819]=1
df["PlacedOrNot"].iloc[820]=1
df["PlacedOrNot"].iloc[837]=1
df["PlacedOrNot"].iloc[838]=1


df["PlacedOrNot"].iloc[827]=1
df["PlacedOrNot"].iloc[840]=1
df["PlacedOrNot"].iloc[841]=1
df["PlacedOrNot"].iloc[845]=1

df["PlacedOrNot"].iloc[854]=1
df["PlacedOrNot"].iloc[858]=1
df["PlacedOrNot"].iloc[864]=1
df["PlacedOrNot"].iloc[870]=1

df["PlacedOrNot"].iloc[876]=1
df["PlacedOrNot"].iloc[892]=1
df["PlacedOrNot"].iloc[893]=1
df["PlacedOrNot"].iloc[894]=1

df["PlacedOrNot"].iloc[932]=1
df["PlacedOrNot"].iloc[933]=1
df["PlacedOrNot"].iloc[934]=1
df["PlacedOrNot"].iloc[935]=1

df["PlacedOrNot"].iloc[915]=1
df["PlacedOrNot"].iloc[916]=1
df["PlacedOrNot"].iloc[922]=1
df["PlacedOrNot"].iloc[929]=1

df["PlacedOrNot"].iloc[942]=1
df["PlacedOrNot"].iloc[940]=1
df["PlacedOrNot"].iloc[945]=1
df["PlacedOrNot"].iloc[946]=1

df["PlacedOrNot"].iloc[948]=1
df["PlacedOrNot"].iloc[949]=1
df["PlacedOrNot"].iloc[951]=1
df["PlacedOrNot"].iloc[955]=1

df["PlacedOrNot"].iloc[958]=1
df["PlacedOrNot"].iloc[959]=1
df["PlacedOrNot"].iloc[962]=1
df["PlacedOrNot"].iloc[963]=1

df["PlacedOrNot"].iloc[973]=1
df["PlacedOrNot"].iloc[975]=1
df["PlacedOrNot"].iloc[984]=1
df["PlacedOrNot"].iloc[988]=1

df["PlacedOrNot"].iloc[991]=1
df["PlacedOrNot"].iloc[993]=1
df["PlacedOrNot"].iloc[994]=1
df["PlacedOrNot"].iloc[995]=1

df["PlacedOrNot"].iloc[996]=1
df["PlacedOrNot"].iloc[999]=1
df["PlacedOrNot"].iloc[1003]=1
df["PlacedOrNot"].iloc[1006]=1

df["PlacedOrNot"].iloc[1007]=1
df["PlacedOrNot"].iloc[1011]=1
df["PlacedOrNot"].iloc[1013]=1
df["PlacedOrNot"].iloc[1015]=1

df["PlacedOrNot"].iloc[1027]=1
df["PlacedOrNot"].iloc[1031]=1
df["PlacedOrNot"].iloc[1033]=1
df["PlacedOrNot"].iloc[1035]=1
# Out:
# C:\Users\2192a\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df[1000:1060]
# Out:
#       index  Age  Gender                         Stream  Internships  CGPA  \
# 1000   1926   22    Male         Information Technology            2     8
# 1001   1911   22    Male         Information Technology            1     8
# 1002   2395   21  Female               Computer Science            1     8
# 1003   2379   22    Male               Computer Science            1     7
# 1004    813   22    Male                     Electrical            2     6
# 1005    678   21    Male                          Civil            1     7
# 1006   1631   21    Male         Information Technology            2     7
# 1007   1646   22    Male         Information Technology            2     7
# 1008   1152   21    Male  Electronics And Communication            1     6
# 1009    351   21    Male                     Mechanical            1     8
# 1010   1704   22    Male         Information Technology            1     8
# ...

# %%
sns.catplot(x="PlacedOrNot", hue="Stream", kind="count",
            data=df,aspect=3)

# %%
df.corr()
# Out:
#                       index       Age  Internships      CGPA    Hostel  \
# index              1.000000  0.036240     0.174589 -0.018380 -0.355697
# Age                0.036240  1.000000     0.006552 -0.119787  0.003042
# Internships        0.174589  0.006552     1.000000  0.023496  0.004617
# CGPA              -0.018380 -0.119787     0.023496  1.000000  0.014991
# Hostel            -0.355697  0.003042     0.004617  0.014991  1.000000
# HistoryOfBacklogs -0.037292 -0.042586    -0.015118  0.002576  0.103506
# PlacedOrNot        0.069997  0.046943     0.179334  0.588648 -0.038182
#
#                    HistoryOfBacklogs  PlacedOrNot
# index                      -0.037292     0.069997
# Age                        -0.042586     0.046943
# Internships                -0.015118     0.179334
# CGPA                        0.002576     0.588648
# Hostel                      0.103506    -0.038182
# HistoryOfBacklogs           1.000000    -0.022337
# ...

# %%
df['Height'][0:150]= np.random.randint(147, 189, 150)
df['Height'][150:450]= np.random.randint(156, 183, 300)
df['Height'][450:750]= np.random.randint(163, 187, 300)
df['Height'][750:986]= np.random.randint(145, 179, 236)
# Out:
# <ipython-input-165-f3d566822ec2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Height'][0:150]= np.random.randint(147, 189, 150)
# C:\Users\2192a\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# <ipython-input-165-f3d566822ec2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.describe()
# Out:
#              index          Age  Internships         CGPA       Hostel  \
# count  2966.000000  2966.000000  2966.000000  2966.000000  2966.000000
# mean   1502.282873    21.485840     0.703641     7.073837     0.269049
# std     865.690877     1.324933     0.740197     0.967748     0.443540
# min       1.000000    19.000000     0.000000     5.000000     0.000000
# 25%     753.250000    21.000000     0.000000     6.000000     0.000000
# 50%    1520.500000    21.000000     1.000000     7.000000     0.000000
# 75%    2259.000000    22.000000     1.000000     8.000000     1.000000
# max    2965.000000    30.000000     3.000000     9.000000     1.000000
#
#        HistoryOfBacklogs  PlacedOrNot
# count        2966.000000  2966.000000
# mean            0.192178     0.552596
# std             0.394079     0.497310
# min             0.000000     0.000000
# 25%             0.000000     0.000000
# 50%             0.000000     1.000000
# 75%             0.000000     1.000000
# ...

# %%
df
# Out:
#       Age  Gender                         Stream  Internships  CGPA  Hostel  \
# 0      22    Male  Electronics And Communication            1     8       1
# 1      21  Female               Computer Science            0     7       1
# 2      22  Female         Information Technology            1     6       0
# 3      21    Male         Information Technology            0     8       0
# 4      22    Male                     Mechanical            0     8       1
# ...   ...     ...                            ...          ...   ...     ...
# 2961   23    Male         Information Technology            0     7       0
# 2962   23    Male                     Mechanical            1     7       1
# 2963   22    Male         Information Technology            1     7       0
# 2964   22    Male               Computer Science            1     7       0
# 2965   23    Male                          Civil            0     8       0
#
#       HistoryOfBacklogs  PlacedOrNot
# ...

# %%
df=df.drop(columns="index")

# %%
for i in range(986):
    if df['Age'].iloc[i]>=49:
        df['PremiumPrice'].iloc[i]=29000
    elif df['Age'].iloc[i]<=29:
        df['PremiumPrice'].iloc[i]=19000
    elif df['Age'].iloc[i]<=49 and df['Age'].iloc[i]>=29:
        df['PremiumPrice'].iloc[i]=23000
for i in range(986):    
    if df['Age'].iloc[i]<= 29 and df['AnyChronicDiseases'].iloc[i]==0:
        df['PremiumPrice'].iloc[i]=15000
    elif df['Age'].iloc[i]>= 33 and df['NumberOfMajorSurgeries'].iloc[i]>=2:
        df['PremiumPrice'].iloc[i]=28000
    elif df['Age'].iloc[i]>= 33 and df['NumberOfMajorSurgeries'].iloc[i]>=2:
        df['PremiumPrice'].iloc[i]=31000
    elif df['Age'].iloc[i]>= 65 and df['NumberOfMajorSurgeries'].iloc[i]>=1:
        df['PremiumPrice'].iloc[i]=35000
    elif df['Age'].iloc[i]>= 29 and df['AnyTransplants'].iloc[i]==1:
        df['PremiumPrice'].iloc[i]=38000
    elif df['Age'].iloc[i]>= 45 and df['Weight'].iloc[i]>=95:
        df['PremiumPrice'].iloc[i]=35000
    elif df['Age'].iloc[i]>= 45 and df['Weight'].iloc[i]<70:
        df['PremiumPrice'].iloc[i]=25000
    elif df['Age'].iloc[i]<= 33 and df['Weight'].iloc[i]<68:
        df['PremiumPrice'].iloc[i]=21000
    elif df['Age'].iloc[i]>= 40 and df['AnyChronicDiseases'].iloc[i]==1:
        df['PremiumPrice'].iloc[i]=30000
    elif df['Age'].iloc[i]<=34 and df['HistoryOfCancerInFamily'].iloc[i]==1:
        df['PremiumPrice'].iloc[i]=25000
    elif df['Age'].iloc[i]>= 35 and df['HistoryOfCancerInFamily'].iloc[i]==1:
        df['PremiumPrice'].iloc[i]=31000
    elif df['AnyTransplants'].iloc[i]==1 and df['Age'].iloc[i]<35:
        df['PremiumPrice'].iloc[i]=38000
    elif df['HistoryOfCancerInFamily'].iloc[i]== 1 and df['Age'].iloc[i]>34 and df["AnyTransplants"]==1:
        df['PremiumPrice'].iloc[i]=39000
# Out:
# C:\Users\2192a\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df["Internships"]=df["Internships"].astype(int)
df["Hostel"]=df["Hostel"].astype(int)
df["HistoryOfBacklogs"]=df["HistoryOfBacklogs"].astype(int)
df["PlacedOrNot"]=df["PlacedOrNot"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2966 entries, 0 to 2965
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              2966 non-null   int32
#  1   Age                2966 non-null   int32
#  2   Gender             2966 non-null   object
#  3   Stream             2966 non-null   object
#  4   Internships        2966 non-null   int32
#  5   CGPA               2966 non-null   int32
#  6   Hostel             2966 non-null   int32
#  7   HistoryOfBacklogs  2966 non-null   int32
#  8   PlacedOrNot        2966 non-null   int32
# dtypes: int32(7), object(2)
# memory usage: 127.6+ KB

# %%
df["PremiumPrice"].value_counts()
# Out:
# 23000    250
# 15000    205
# 28000    133
# 25000    104
# 29000     73
# 30000     46
# 35000     41
# 38000     35
# 31000     31
# 21000     26
# 19000     16
# 26000      7
# 39000      5
# 24000      4
# 32000      3
# 34000      2
# 36000      2
# 22000      1
# 17000      1
# 40000      1
# Name: PremiumPrice, dtype: int64

# %%
sns.catplot(y="PlacedOrNot", x="Stream", kind="bar",
            data=df,aspect=3)

# %%
sns.catplot(y="BloodPressureProblems", x="Age", kind="bar",
            data=df,aspect=3)

# %%
df["PremiumPrice"].iloc[58]=24000
df["PremiumPrice"].iloc[984]=39000
df["PremiumPrice"].iloc[976]=39000
df["PremiumPrice"].iloc[978]=17000
df["PremiumPrice"].iloc[926]=39000
df["PremiumPrice"].iloc[928]=39000
df["PremiumPrice"].iloc[22]=32000
df["PremiumPrice"].iloc[46]=32000
df["PremiumPrice"].iloc[53]=32000
df["PremiumPrice"].iloc[212]=24000
df["PremiumPrice"].iloc[217]=24000
df["PremiumPrice"].iloc[203]=26000
df["PremiumPrice"].iloc[202]=26000
df["PremiumPrice"].iloc[213]=22000
df["PremiumPrice"].iloc[219]=26000
df["PremiumPrice"].iloc[204]=39000
df["PremiumPrice"].iloc[295]=40000
df["PremiumPrice"].iloc[311]=24000
df["PremiumPrice"].iloc[334]=34000
df["PremiumPrice"].iloc[324]=26000
df["PremiumPrice"].iloc[280]=26000
df["PremiumPrice"].iloc[333]=18000
df["PremiumPrice"].iloc[444]=18000
df["PremiumPrice"].iloc[446]=16000
df["PremiumPrice"].iloc[448]=16000
df["PremiumPrice"].iloc[450]=16000
df["PremiumPrice"].iloc[434]=int(20000)
df["PremiumPrice"].iloc[765]=int(30000)
df["PremiumPrice"].iloc[666]=int(30000)
df["PremiumPrice"].iloc[788]=int(27000)

# %%
df.describe()
# Out:
#             index         Age    Diabetes  BloodPressureProblems  \
# count  986.000000  986.000000  986.000000             986.000000
# mean   494.987830   41.745436    0.330629               0.426978
# std    289.899944   13.963371    0.470678               0.494890
# min      1.000000   18.000000    0.000000               0.000000
# 25%    232.250000   30.000000    0.000000               0.000000
# 50%    494.000000   42.000000    0.000000               0.000000
# 75%    767.500000   53.000000    1.000000               1.000000
# max    985.000000   66.000000    1.000000               1.000000
#
#        AnyTransplants  AnyChronicDiseases      Height      Weight  \
# count      986.000000          986.000000  986.000000  986.000000
# mean         0.055781            0.180527  168.182556   76.950304
# std          0.229615            0.384821   10.098155   14.265096
# min          0.000000            0.000000  145.000000   51.000000
# ...

# %%
df["Height"]=df["Height"].astype(int)
df["Weight"]=df["Weight"].astype(int)
df["PremiumPrice"]=df["PremiumPrice"].astype(int)

# %%
df.corr()
# Out:
#                             index       Age  Diabetes  BloodPressureProblems  \
# index                    1.000000  0.001593  0.143445               0.241746
# Age                      0.001593  1.000000  0.210908               0.244888
# Diabetes                 0.143445  0.210908  1.000000               0.127727
# BloodPressureProblems    0.241746  0.244888  0.127727               1.000000
# AnyTransplants           0.006324 -0.008549 -0.036652              -0.024538
# AnyChronicDiseases       0.079957  0.051072 -0.089428               0.045424
# Height                  -0.003846  0.039879 -0.003783              -0.037926
# Weight                  -0.016727 -0.018590 -0.024563              -0.061016
# KnownAllergies          -0.273543 -0.024416 -0.080102              -0.011550
# HistoryOfCancerInFamily -0.030849 -0.027623 -0.055527               0.048239
# NumberOfMajorSurgeries   0.151138  0.429181  0.122722               0.251568
# ...

# %%
for i in range(986):
    if df['Age'].iloc[i]>=19 and df['Age'].iloc[i]<=23 and df['index'].iloc[i]%4==0:
        df["Diabetes"].iloc[i]=int(1)
for i in range(986):
    if df['Age'].iloc[i]>=45 and df['Age'].iloc[i]<=68 and df['index'].iloc[i]%4==1:
        df["Diabetes"].iloc[i]=int(1)

# %%
for i in range(986):
    if df['Age'].iloc[i]>=19 and df['Age'].iloc[i]<=21 and df['index'].iloc[i]%5==0:
        df["BloodPressureProblems"].iloc[i]=int(1)
for i in range(986):
    if df['Age'].iloc[i]>=45 and df['Age'].iloc[i]<=68 and df['index'].iloc[i]%4==0:
        df["BloodPressureProblems"].iloc[i]=int(1)

# %%
df=df.astype(int)

# %%
df
# Out:
#      index  Age  Diabetes  BloodPressureProblems  AnyTransplants  \
# 0       47   45         0                      0               0
# 1      193   60         1                      0               0
# 2      542   36         1                      1               0
# 3      985   52         1                      1               0
# 4      422   38         0                      0               0
# ..     ...  ...       ...                    ...             ...
# 981    632   18         0                      0               0
# 982    181   64         1                      1               0
# 983    232   56         0                      1               0
# 984    182   47         1                      1               0
# 985    798   21         0                      0               0
#
#      AnyChronicDiseases  Height  Weight  KnownAllergies  \
# 0                     0     155      57               0
# 1                     0     180      73               0
# ...

# %%
df["BloodPressureProblems"].iloc[512]=1
df["PremiumPrice"].iloc[556]=26000
df["PremiumPrice"].iloc[555]=26000
df["PremiumPrice"].iloc[558]=34000
df["PremiumPrice"].iloc[531]=36000
df["PremiumPrice"].iloc[516]=36000
df["PremiumPrice"].iloc[650]=32000

# %%
sns.pairplot(data=df)

# %%
df.corr()
# Out:
#                             index       Age  Diabetes  BloodPressureProblems  \
# index                    1.000000  0.001593  0.143445               0.241746
# Age                      0.001593  1.000000  0.210908               0.244888
# Diabetes                 0.143445  0.210908  1.000000               0.127727
# BloodPressureProblems    0.241746  0.244888  0.127727               1.000000
# AnyTransplants           0.006324 -0.008549 -0.036652              -0.024538
# AnyChronicDiseases       0.079957  0.051072 -0.089428               0.045424
# Height                  -0.003846  0.039879 -0.003783              -0.037926
# Weight                  -0.016727 -0.018590 -0.024563              -0.061016
# KnownAllergies          -0.273543 -0.024416 -0.080102              -0.011550
# HistoryOfCancerInFamily -0.030849 -0.027623 -0.055527               0.048239
# NumberOfMajorSurgeries   0.151138  0.429181  0.122722               0.251568
# ...

# %%
df["PremiumPrice"].value_counts().sum()
# Out:
# 986

# %%
df["PremiumPrice"].iloc[333]=18000
df["PremiumPrice"].iloc[444]=18000
df["PremiumPrice"].iloc[446]=16000
df["PremiumPrice"].iloc[448]=16000
df["PremiumPrice"].iloc[450]=16000
df["PremiumPrice"].iloc[434]=int(20000)
df["PremiumPrice"].iloc[765]=int(30000)
df["PremiumPrice"].iloc[666]=int(30000)
df["PremiumPrice"].iloc[788]=int(27000)

# %%
df.columns
# Out:
# Index(['index', 'Age', 'Diabetes', 'BloodPressureProblems', 'AnyTransplants',
#        'AnyChronicDiseases', 'Height', 'Weight', 'KnownAllergies',
#        'HistoryOfCancerInFamily', 'NumberOfMajorSurgeries', 'PremiumPrice'],
#       dtype='object')

# %%
sns.displot(df, x="Stream")

# %%
df=df.drop(columns=["index"])

# %%
df.to_csv("collegePlace.csv",index=False)

# %%
x=pd.read_csv("Medicalpremium.csv")

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      986 non-null    int64
#  1   Diabetes                 986 non-null    int64
#  2   BloodPressureProblems    986 non-null    int64
#  3   AnyTransplants           986 non-null    int64
#  4   AnyChronicDiseases       986 non-null    int64
#  5   Height                   986 non-null    int64
#  6   Weight                   986 non-null    int64
#  7   KnownAllergies           986 non-null    int64
#  8   HistoryOfCancerInFamily  986 non-null    int64
#  9   NumberOfMajorSurgeries   986 non-null    int64
#  10  PremiumPrice             986 non-null    int64
# dtypes: int64(11)
# memory usage: 84.9 KB

# %%
x.describe()
# Out:
#               Age    Diabetes  BloodPressureProblems  AnyTransplants  \
# count  986.000000  986.000000             986.000000      986.000000
# mean    41.745436    0.419878               0.468560        0.055781
# std     13.963371    0.493789               0.499264        0.229615
# min     18.000000    0.000000               0.000000        0.000000
# 25%     30.000000    0.000000               0.000000        0.000000
# 50%     42.000000    0.000000               0.000000        0.000000
# 75%     53.000000    1.000000               1.000000        0.000000
# max     66.000000    1.000000               1.000000        1.000000
#
#        AnyChronicDiseases      Height      Weight  KnownAllergies  \
# count          986.000000  986.000000  986.000000      986.000000
# mean             0.180527  168.182556   76.950304        0.215010
# std              0.384821   10.098155   14.265096        0.411038
# min              0.000000  145.000000   51.000000        0.000000
# ...

# %%
x.corr()
# Out:
#                               Age  Diabetes  BloodPressureProblems  \
# Age                      1.000000  0.210908               0.244888
# Diabetes                 0.210908  1.000000               0.127727
# BloodPressureProblems    0.244888  0.127727               1.000000
# AnyTransplants          -0.008549 -0.036652              -0.024538
# AnyChronicDiseases       0.051072 -0.089428               0.045424
# Height                   0.039879 -0.003783              -0.037926
# Weight                  -0.018590 -0.024563              -0.061016
# KnownAllergies          -0.024416 -0.080102              -0.011550
# HistoryOfCancerInFamily -0.027623 -0.055527               0.048239
# NumberOfMajorSurgeries   0.429181  0.122722               0.251568
# PremiumPrice             0.697540  0.076209               0.167097
#
#                          AnyTransplants  AnyChronicDiseases    Height  \
# Age                           -0.008549            0.051072  0.039879
# ...
